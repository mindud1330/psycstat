# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# 가우시안 정규 분포의 평균과 표준편차
mean = 0
std_dev = 1

# 정규 분포를 따르는 표본값 생성
sample_data = np.random.normal(mean, std_dev, 1000)

# 히스토그램 그리기
plt.hist(sample_data, bins=30, density=True, alpha=0.6, color='g')

# 가우시안 정규 분포의 확률밀도함수 그리기
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std_dev)
plt.plot(x, p, 'k', linewidth=2)

# 그래프 타이틀과 축 레이블 설정
plt.title('Probability Density Function')
plt.xlabel('Value')
plt.ylabel('Probability Density')

# 그래프 보이기
plt.show()

# %%
import pandas as pd
import seaborn as sns

# CSV file path
file_path = "/content/drive/MyDrive/data/psycstat_data_2024.csv"

# CSV file
df = pd.read_csv(file_path)

# inverse
df["Per5_inverse"] = 6 - df["Per5"]
df["Per9_inverse"] = 6 - df["Per9"]
df["Per10_inverse"] = 6 - df["Per10"]
df["Per15_inverse"] = 6 - df["Per15"]

# Extraversion
ext_cols = ["Per1", "Per9_inverse", "Per14"]
# Agreeableness
agr_cols = ["Per4", "Per12", "Per15_inverse"]
# Conscientiousness
con_cols = ["Per2", "Per6", "Per13"]
# Neuroticism
neu_cols = ["Per5_inverse", "Per7", "Per10_inverse"]

# sum data
df['Ext_sum'] = df[ext_cols].apply(lambda row: row.sum(skipna=True), axis=1)
df['Agr_sum'] = df[agr_cols].apply(lambda row: row.sum(skipna=True), axis=1)
df['Con_sum'] = df[con_cols].apply(lambda row: row.sum(skipna=True), axis=1)
df['Neu_sum'] = df[neu_cols].apply(lambda row: row.sum(skipna=True), axis=1)

# graph
sns.histplot(data = df.Ext_sum, kde = True)
# Out:
# <Axes: xlabel='Ext_sum', ylabel='Count'>

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# cross table data
data = {
    'Black': [95, 19],
    'non-black': [425, 128]
}

df = pd.DataFrame(data)

# chi-square test
chi2, p, dof, expected = chi2_contingency(cross_table)

# result
print("Chi-square statistic:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
#print("Expected frequencies table:")
#print(expected)
# Out:
# Chi-square statistic: 23.366041768752698
# p-value: 0.00292474529518454
# Degrees of freedom: 8
